# %% [markdown]
# # Analysis of the risk of failure of the O-rings on the Challenger shuttle

# %% [markdown]
# On January 27, 1986, the day before the takeoff of the shuttle _Challenger_, had
# a three-hour teleconference was held between
# Morton Thiokol (the manufacturer of one of the engines) and NASA. The
# discussion focused on the consequences of the
# temperature at take-off of 31°F (just below
# 0°C) for the success of the flight and in particular on the performance of the
# O-rings used in the engines. Indeed, no test
# had been performed at this temperature.
#
# The following study takes up some of the analyses carried out that
# night with the objective of assessing the potential influence of
# the temperature and pressure to which the O-rings are subjected
# on their probability of malfunction. Our starting point is
# the results of the experiments carried out by NASA engineers
# during the six years preceding the launch of the shuttle
# Challenger.

# %% [markdown]
# ## Loading the data
# We start by loading this data:

# %%
import numpy as np
import pandas as pd
data = pd.read_csv("shuttle.csv")
data
# Out:
#         Date  Count  Temperature  Pressure  Malfunction
# 0    4/12/81      6           66        50            0
# 1   11/12/81      6           70        50            1
# 2    3/22/82      6           69        50            0
# 3   11/11/82      6           68        50            0
# 4    4/04/83      6           67        50            0
# 5    6/18/82      6           72        50            0
# 6    8/30/83      6           73       100            0
# 7   11/28/83      6           70       100            0
# 8    2/03/84      6           57       200            1
# 9    4/06/84      6           63       200            1
# 10   8/30/84      6           70       200            1
# 11  10/05/84      6           78       200            0
# 12  11/08/84      6           67       200            0
# 13   1/24/85      6           53       200            2
# 14   4/12/85      6           67       200            0
# 15   4/29/85      6           75       200            0
# ...

# %% [markdown]
# The data set shows us the date of each test, the number of O-rings (there are 6 on the main launcher), the temperature (in Fahrenheit) and pressure (in psi), and finally the number of identified malfunctions.

# %% [markdown]
# ## Graphical inspection
# Flights without incidents do not provide any information
# on the influence of temperature or pressure on malfunction.
# We thus focus on the experiments in which at least one O-ring
# was defective.

# %%
data = data[data.Malfunction>0]
data
# Out:
#         Date  Count  Temperature  Pressure  Malfunction
# 1   11/12/81      6           70        50            1
# 8    2/03/84      6           57       200            1
# 9    4/06/84      6           63       200            1
# 10   8/30/84      6           70       200            1
# 13   1/24/85      6           53       200            2
# 20  10/30/85      6           75       200            2
# 22   1/12/86      6           58       200            1

# %% [markdown]
# We have a high temperature variability but
# the pressure is almost always 200, which should
# simplify the analysis.
#
# How does the frequency of failure vary with temperature?

# %%
# %matplotlib inline
pd.set_option('mode.chained_assignment',None) # this removes a useless warning from pandas
import matplotlib.pyplot as plt

data["Frequency"]=data.Malfunction/data.Count
data.plot(x="Temperature",y="Frequency",kind="scatter",ylim=[0,1])
plt.grid(True)

# %% [markdown]
# At first glance, the dependence does not look very important, but let's try to
# estimate the impact of temperature $t$ on the probability of O-ring malfunction.

# %% [markdown]
# ## Estimation of the temperature influence
#
# Suppose that each of the six O-rings is damaged with the same
# probability and independently of the others and that this probability
# depends only on the temperature. If $p(t)$ is this probability, the
# number $D$ of malfunctioning O-rings during a flight at
# temperature $t$ follows a binomial law with parameters $n=6$ and
# $p=p(t)$. To link $p(t)$ to $t$, we will therefore perform a
# logistic regression.

# %%
import statsmodels.api as sm

data["Success"]=data.Count-data.Malfunction
data["Intercept"]=1

logmodel=sm.GLM(data['Frequency'], data[['Intercept','Temperature']], family=sm.families.Binomial(sm.families.links.logit)).fit()

logmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              Frequency   No. Observations:                    7
# Model:                            GLM   Df Residuals:                        5
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2.5250
# Date:                Wed, 12 Nov 2025   Deviance:                      0.22231
# Time:                        19:41:53   Pearson chi2:                    0.236
# No. Iterations:                     4   Covariance Type:             nonrobust
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %% [markdown]
# The most likely estimator of the temperature parameter is 0.0014
# and the standard error of this estimator is 0.122, in other words we
# cannot distinguish any particular impact and we must take our
# estimates with caution.

# %% [markdown]
# ## Estimation of the probability of O-ring malfunction
#
# The expected temperature on the take-off day is 31°F. Let's try to
# estimate the probability of O-ring malfunction at
# this temperature from the model we just built:

# %%
# %matplotlib inline
data_pred = pd.DataFrame({'Temperature': np.linspace(start=30, stop=90, num=121), 'Intercept': 1})
data_pred['Frequency'] = logmodel.predict(data_pred[['Intercept','Temperature']])
data_pred.plot(x="Temperature",y="Frequency",kind="line",ylim=[0,1])
plt.scatter(x=data["Temperature"],y=data["Frequency"])
plt.grid(True)

# %% [markdown]
# As expected from the initial data, the
# temperature has no significant impact on the probability of failure of the
# O-rings. It will be about 0.2, as in the tests
# where we had a failure of at least one joint. Let's get back
# to the initial dataset to estimate the probability of failure:

# %%
data = pd.read_csv("shuttle.csv")
print(np.sum(data.Malfunction)/np.sum(data.Count))
# Out:
# 0.06521739130434782

# %% [markdown]
# This probability is thus about $p=0.065$. Knowing that there is
# a primary and a secondary O-ring on each of the three parts of the
# launcher, the probability of failure of both joints of a launcher
# is $p^2 \approx 0.00425$. The probability of failure of any one of the
# launchers is $1-(1-p^2)^3 \approx 1.2%$.  That would really be
# bad luck.... Everything is under control, so the takeoff can happen
# tomorrow as planned.
#
# But the next day, the Challenger shuttle exploded and took away
# with her the seven crew members. The public was shocked and in
# the subsequent investigation, the reliability of the
# O-rings was questioned. Beyond the internal communication problems
# of NASA, which have a lot to do with this fiasco, the previous analysis
# includes (at least) a small problem.... Can you find it?
# You are free to modify this analysis and to look at this dataset
# from all angles in order to to explain what's wrong.

# %% [markdown]
# ## Estimation of the probability of failure under low temperatures
#
# The error on the previous analysis is that we have more test data under high temperatures and we are using only data from malfunction tests to conclude that the temperature has no significant impact on the outcome of the test, when there is actual evidence to support this claim.

# %%
data = pd.read_csv("shuttle.csv")
data.plot(x="Temperature",y="Malfunction",kind="scatter")
plt.grid(True)

# %% [markdown]
# Looking at the data, the main finding is simple: O-ring failure is strongly tied to cold temperatures. Every test flight launched at 65°F or colder had at least one O-ring malfunction. On the flip side, most flights at 65°F or warmer had no malfunctions, with only three total exceptions occurring at 70°F and 75°F.
#
# We can test this hypothesis by analyzing the Failure boolean outcome for each individual test, where a test is marked as a failure if at least one malfunction occurred during the experiment. Then, we can fit a GLM model to the dataset, including both successful and failed tests.

# %%
import statsmodels.api as sm

data['Failure'] = (data['Malfunction'] >= 1).astype(int)
data["Intercept"] = 1

logmodel_temp=sm.GLM(data['Failure'], data[['Intercept','Temperature']], family=sm.families.Binomial(sm.families.links.logit)).fit()

logmodel_temp.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                Failure   No. Observations:                   23
# Model:                            GLM   Df Residuals:                       21
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -10.158
# Date:                Wed, 12 Nov 2025   Deviance:                       20.315
# Time:                        21:04:24   Pearson chi2:                     23.2
# No. Iterations:                     5   Covariance Type:             nonrobust
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %% [markdown]
# As we can see, the coefficient for Temperature is $coef=-0.2322$, , indicating an inverse relationship between Temperature and Failure — in other words, lower temperatures are associated with a higher likelihood of failure. This is further supported by the p-value of $P>|z|=0.032$, showing that Temperature is a statistically significant factor in O-ring failure.
#
# We can now try to make a regression of the Failure variable with Temperature, using the same technique that was used before.

# %%
# %matplotlib inline
data_pred = pd.DataFrame({'Temperature': np.linspace(start=40, stop=90, num=121), 'Intercept': 1})
data_pred['Failure'] = logmodel_temp.predict(data_pred[['Intercept','Temperature']])
data_pred.plot(x="Temperature",y="Failure",kind="line")
plt.scatter(x=data["Temperature"],y=data["Failure"])
plt.grid(True)

# %% [markdown]
# We can now clearly see a correlation between the two variables when successful launches are also included, indicating that lower temperatures lead to a higher number of experiments with at least one malfunction.

# %% [markdown]
# ## Understanding the role of pressure for failures
#
# So far, we have only discussed the effects of Temperature on the experiment outcomes. We can now perform the same GLM analysis to examine whether Pressure has any significant impact on the occurrence of failures.

# %%
import statsmodels.api as sm

logmodel_pressure=sm.GLM(data['Failure'], data[['Intercept','Pressure']], family=sm.families.Binomial(sm.families.links.logit)).fit()

logmodel_pressure.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                Failure   No. Observations:                   23
# Model:                            GLM   Df Residuals:                       21
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -13.268
# Date:                Wed, 12 Nov 2025   Deviance:                       26.536
# Time:                        21:04:38   Pearson chi2:                     23.3
# No. Iterations:                     4   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# The GLM analysis for Pressure shows a coefficient of $coef = 0.0101$, suggesting a very weak positive relationship between Pressure and the likelihood of Failure. However, the corresponding p-value of $P>|z|=0.231$ indicates that this effect is not statistically significant. Therefore, we cannot conclude that Pressure has a meaningful influence on the occurrence of failures in the experiments.

# %% [markdown]
# ## Calculating the real chance of Failure under launch conditions
#
# Based on the data and previous analysis, we can now estimate the actual probability of Failure (i.e., at least one O-ring malfunction) under the specific conditions of the launch. As mentioned earlier, the temperature on the launch day was 31°F, and since Pressure was found to be statistically insignificant in this analysis, it will not be considered in the calculation.

# %%
launch_condition = pd.DataFrame({'Intercept': [1], 'Temperature': [31]})

predicted_failure_prob = logmodel_temp.predict(launch_condition[['Intercept', 'Temperature']])
predicted_failure_prob
# Out:
# 0    0.999609
# dtype: float64

# %% [markdown]
# We can conclude that there was 99.96% chance of at least one O-ring malfunction under the conditions of the launch.
